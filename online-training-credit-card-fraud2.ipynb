# %%
import joblib

# %%
mymodel = joblib.load('fraud-detection-model-v1.pkl')

# %%
type(mymodel)
# Out:
# sklearn.linear_model._stochastic_gradient.SGDClassifier

# %% [markdown]
# # load new data

# %%
import pandas as pd

# %%
df = pd.read_csv("creditcard_3.csv", header=None)

# %%
df.shape
# Out:
# (2000, 31)

# %%
df.head()
# Out:
#      0         1         2         3         4         5         6         7   \
# 0  3639 -0.377328  0.606012  1.474296 -0.373168  0.551367 -0.602437  0.558113
# 1  3640 -0.556558  0.929513  3.271154  3.112619  0.100550  1.515331 -0.083776
# 2  3641  1.309282  0.399733  0.319851  0.622603  0.096517 -0.436800  0.037837
# 3  3641 -1.654176  1.434840 -0.999271 -0.057036  1.728809  3.760631 -0.129790
# 4  3642  1.137227 -0.004168  0.736363  1.004318 -0.646759 -0.476669 -0.266511
#
#          8         9   ...        21        22        23        24        25  \
# 0 -0.229391  1.134284  ... -0.319543 -0.729032  0.018198 -0.117900 -0.596078
# 1  0.221001  0.345484  ... -0.237860 -0.035994 -0.186225 -0.017544 -0.101975
# 2 -0.298836  1.214750  ... -0.445632 -0.995838  0.024689 -0.489914  0.341929
# 3  0.825041  0.890528  ... -0.031248 -0.110596 -0.146247  1.006181 -0.217530
# 4 -0.019929  1.653650  ... -0.318746 -0.630429  0.033863  0.487558  0.325825
#
# ...

# %%
df.iloc[:,30].value_counts()
# Out:
# 30
# 0    1999
# 1       1
# Name: count, dtype: int64

# %%
y=df.iloc[:,30]  # select the last row
x=df.iloc[:,0:30] # select all rows except last row

# %%
mymodel.partial_fit(x,y, classes=[0,1])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(
# SGDClassifier()

# %%
mymodel.score(x,y)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(
# 0.9995
